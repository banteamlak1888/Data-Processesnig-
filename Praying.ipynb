# %% [markdown]
# <a href="https://colab.research.google.com/github/banteamlak1888/Data-Processesnig-/blob/main/Praying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("some think hapn whay?")
# Out:
# some think hapn whay?

# %%
print("plc God Help me! I need you support , any stuation are complecated so you coldow evry movment rather than stragle me ")
# Out:
# plc God Help me! I need you support , any stuation are complecated so you coldow evry movment rather than stragle me

# %%
print("because you can do!!")
# Out:
# because you can do!!
